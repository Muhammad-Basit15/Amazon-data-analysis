# %%
import pandas as pd
import numpy as np

# %% [markdown]
# **Importing Data file**

# %%
df=pd.read_csv("/content/Amazon Sale Report.csv")
# Out:
# /tmp/ipython-input-140-1562293219.py:1: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("/content/Amazon Sale Report.csv")

# %%
df
# Out:
#          index             Order ID      Date                        Status  \
# 0            0  405-8078784-5731545  04-30-22                     Cancelled
# 1            1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2            2  404-0687676-7273146  04-30-22                       Shipped
# 3            3  403-9615377-8133951  04-30-22                     Cancelled
# 4            4  407-1069790-7240320  04-30-22                       Shipped
# ...        ...                  ...       ...                           ...
# 128970  128970  406-6001380-7673107  05-31-22                       Shipped
# 128971  128971  402-9551604-7544318  05-31-22                       Shipped
# 128972  128972  407-9547469-3152358  05-31-22                       Shipped
# 128973  128973  402-6184140-0545956  05-31-22                       Shipped
# 128974  128974  408-7436540-8728312  05-31-22                       Shipped
#
# ...

# %% [markdown]
# **Data Cleaning**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128975 entries, 0 to 128974
# Data columns (total 24 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               128975 non-null  int64
#  1   Order ID            128975 non-null  object
#  2   Date                128975 non-null  object
#  3   Status              128975 non-null  object
#  4   Fulfilment          128975 non-null  object
#  5   Sales Channel       128975 non-null  object
#  6   ship-service-level  128975 non-null  object
#  7   Style               128975 non-null  object
#  8   SKU                 128975 non-null  object
#  9   Category            128975 non-null  object
#  10  Size                128975 non-null  object
#  11  ASIN                128975 non-null  object
#  12  Courier Status      122103 non-null  object
#  13  Qty                 128975 non-null  int64
#  14  currency            121180 non-null  object
# ...

# %%
df.describe()
# Out:
#                index            Qty         Amount  ship-postal-code
# count  128975.000000  128975.000000  121180.000000     128942.000000
# mean    64487.000000       0.904431     648.561465     463966.236509
# std     37232.019822       0.313354     281.211687     191476.764941
# min         0.000000       0.000000       0.000000     110001.000000
# 25%     32243.500000       1.000000     449.000000     382421.000000
# 50%     64487.000000       1.000000     605.000000     500033.000000
# 75%     96730.500000       1.000000     788.000000     600024.000000
# max    128974.000000      15.000000    5584.000000     989898.000000

# %%
df.dtypes
# Out:
# index                   int64
# Order ID               object
# Date                   object
# Status                 object
# Fulfilment             object
# Sales Channel          object
# ship-service-level     object
# Style                  object
# SKU                    object
# Category               object
# Size                   object
# ASIN                   object
# Courier Status         object
# Qty                     int64
# currency               object
# Amount                float64
# ship-city              object
# ship-state             object
# ship-postal-code      float64
# ship-country           object
# promotion-ids          object
# B2B                      bool
# fulfilled-by           object
# Unnamed: 22            object
# dtype: object

# %%
df=df.drop(("Unnamed: 22"),axis= True)

# %%
df.head()
# Out:
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
# 3      3  403-9615377-8133951  04-30-22                     Cancelled
# 4      4  407-1069790-7240320  04-30-22                       Shipped
#
#   Fulfilment Sales Channel  ship-service-level    Style              SKU  \
# 0   Merchant      Amazon.in           Standard   SET389   SET389-KR-NP-S
# 1   Merchant      Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL
# 2     Amazon      Amazon.in          Expedited  JNE3371    JNE3371-KR-XL
# 3   Merchant      Amazon.in           Standard    J0341       J0341-DR-L
# 4     Amazon      Amazon.in          Expedited  JNE3671  JNE3671-TU-XXXL
#
#         Category  ... Qty currency  Amount    ship-city   ship-state  \
# ...

# %%
df.isnull().sum()
# Out:
# index                     0
# Order ID                  0
# Date                      0
# Status                    0
# Fulfilment                0
# Sales Channel             0
# ship-service-level        0
# Style                     0
# SKU                       0
# Category                  0
# Size                      0
# ASIN                      0
# Courier Status         6872
# Qty                       0
# currency               7795
# Amount                 7795
# ship-city                33
# ship-state               33
# ship-postal-code         33
# ship-country             33
# promotion-ids         49153
# B2B                       0
# fulfilled-by          89698
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["Courier Status"].unique()
# Out:
# array([nan, 'Shipped', 'Cancelled', 'Unshipped'], dtype=object)

# %%
df["Courier Status"]=df["Courier Status"].replace(np.nan,"Cancelled")

# %%
df.isnull().sum()
# Out:
# index                     0
# Order ID                  0
# Date                      0
# Status                    0
# Fulfilment                0
# Sales Channel             0
# ship-service-level        0
# Style                     0
# SKU                       0
# Category                  0
# Size                      0
# ASIN                      0
# Courier Status            0
# Qty                       0
# currency               7795
# Amount                 7795
# ship-city                33
# ship-state               33
# ship-postal-code         33
# ship-country             33
# promotion-ids         49153
# B2B                       0
# fulfilled-by          89698
# dtype: int64

# %%
df["currency"]=df["currency"].replace(np.nan,"INR")
df["Amount"]=df["Amount"].replace(np.nan,0)

# %%
df.isnull().sum()
# Out:
# index                     0
# Order ID                  0
# Date                      0
# Status                    0
# Fulfilment                0
# Sales Channel             0
# ship-service-level        0
# Style                     0
# SKU                       0
# Category                  0
# Size                      0
# ASIN                      0
# Courier Status            0
# Qty                       0
# currency                  0
# Amount                    0
# ship-city                33
# ship-state               33
# ship-postal-code         33
# ship-country             33
# promotion-ids         49153
# B2B                       0
# fulfilled-by          89698
# dtype: int64

# %%
df["ship-city"].unique()
# Out:
# array(['MUMBAI', 'BENGALURU', 'NAVI MUMBAI', ...,
#        'GULABPURA, Distt BHILWARA', 'Prayagraj (ALLAHABAD)', 'Halol'],
#       dtype=object)

# %%
df["ship-city"]
# Out:
# 0              MUMBAI
# 1           BENGALURU
# 2         NAVI MUMBAI
# 3          PUDUCHERRY
# 4             CHENNAI
#              ...
# 128970      HYDERABAD
# 128971       GURUGRAM
# 128972      HYDERABAD
# 128973          Halol
# 128974         Raipur
# Name: ship-city, Length: 128975, dtype: object

# %%
dt = df[df['ship-city'] != 1]

# %%
df=dt

# %%
df
# Out:
#          index             Order ID      Date                        Status  \
# 0            0  405-8078784-5731545  04-30-22                     Cancelled
# 1            1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2            2  404-0687676-7273146  04-30-22                       Shipped
# 3            3  403-9615377-8133951  04-30-22                     Cancelled
# 4            4  407-1069790-7240320  04-30-22                       Shipped
# ...        ...                  ...       ...                           ...
# 128970  128970  406-6001380-7673107  05-31-22                       Shipped
# 128971  128971  402-9551604-7544318  05-31-22                       Shipped
# 128972  128972  407-9547469-3152358  05-31-22                       Shipped
# 128973  128973  402-6184140-0545956  05-31-22                       Shipped
# 128974  128974  408-7436540-8728312  05-31-22                       Shipped
#
# ...

# %%
df['ship-city'] = df['ship-city'].str.title().str.strip()
df['ship-state'] = df['ship-state'].str.title().str.strip()

# %%
df["ship-city"].unique()
# Out:
# array(['Mumbai', 'Bengaluru', 'Navi Mumbai', ..., 'Cherukunnu (P.O)',
#        'Gulabpura, Distt Bhilwara', 'Prayagraj (Allahabad)'], dtype=object)

# %%
df["ship-city"].nunique()
# Out:
# 7297

# %% [markdown]
# **Creating Mapping table for Irregular values**

# %%
# Create cleaned city column.............!
df['ship-city-cleaned'] = df['ship-city'].astype(str).str.strip().str.title()

# Mapping table for standardization...........!
city_mapping = {

    '53Miles': None,
    '7Barasat': 'Barasat',
    'Aburoad': 'Abu Road',
    'Abhayapuri, Bongaigaon': 'Abhayapuri',
    ',Hyderabad': 'Hyderabad',
    '.Gannavaram': 'Gannavaram',
    '.Azamgarh': 'Azamgarh',
    '..Katra': 'Katra',
    ',Raibarely Road Faizabad (Ayodhya)': 'Ayodhya',
    '(Via Cuncolim)Quepem,South Goa': 'Quepem',
    '(Chikmagalur Disterict).     (N.R Pur Thaluku)': 'Chikmagalur',
    'Adajan Gam, Surat': 'Surat',
    '147/19 B Keshab Chandra Sen Street Kolkata Nine Ma': 'Kolkata',
    '116  B. P. M. B Sarani, Uttarpara Kotrung': 'Kolkata',
    '6Th Mile Tadong': 'Tadong',

    # Ahmedabad variants
    'Ahmadabad': 'Ahmedabad',
    'Ahmedabad 380007': 'Ahmedabad',
    'Ahmedabad 380013': 'Ahmedabad',
    'Ahmedabad 380014': 'Ahmedabad',
    'Ahmedabad,': 'Ahmedabad',
    'Ahmedabad.': 'Ahmedabad',
    'Ahmedabadvasna': 'Ahmedabad',
    'Bapunagar,Ahmedabad': 'Ahmedabad',
    'Bodakdev, Ahmedabad': 'Ahmedabad',
    'Bopal Ahmedabad': 'Ahmedabad',
    'Chandkheda, Ahmedabad': 'Ahmedabad',
    'Chandlodia, Ahmedabad': 'Ahmedabad',
    'Dholka, Ahmedabad': 'Ahmedabad',
    'Khodiyar, Ahmedabad': 'Ahmedabad',
    'Ranip,Ahmedabad': 'Ahmedabad',
    'R.C. Technical College Road, Ghatlodia, Ahmedabad': 'Ahmedabad',
    'Sg Highway Ahmedabad': 'Ahmedabad',
    'Shela, Ahmedabad': 'Ahmedabad',
    'South Bopal, Ahmedabad': 'Ahmedabad',

    # Ahmednagar variants........!
    'Ahmadnagar': 'Ahmednagar',
    'Ahmadnagara': 'Ahmednagar',
    'Ahmed Nagar': 'Ahmednagar',
    'Ahmedanagar': 'Ahmednagar',
    'Ahmednagar': 'Ahmednagar',
    'Ahmedpur': 'Ahmednagar',
    'Ahmadpur': 'Ahmednagar',
    'Akole Ahmadnagar District': 'Ahmednagar',
    'Rajur Ahmadnagar District': 'Ahmednagar',
    'Newasa-Phata, Tal-Newasa, Dist-Ahmednagar': 'Ahmednagar',
    'Tal -Newasa Dist- Ahmednagar': 'Ahmednagar',
}

# Replace values using mapping.............!
df['standard_city'] = df['ship-city-cleaned'].replace(city_mapping).fillna(df['ship-city-cleaned'])

# %%
df.standard_city.nunique()
# Out:
# 7255

# %%
unique_cities_df = pd.DataFrame(df['standard_city'].unique(), columns=['standard_city'])

# %%
unique_cities_df
# Out:
#                   standard_city
# 0                        Mumbai
# 1                     Bengaluru
# 2                   Navi Mumbai
# 3                    Puducherry
# 4                       Chennai
# ...                         ...
# 7250           New Delhi 110032
# 7251      Vaishali Nagar Nagpur
# 7252           Cherukunnu (P.O)
# 7253  Gulabpura, Distt Bhilwara
# 7254      Prayagraj (Allahabad)
#
# [7255 rows x 1 columns]

# %%
dt=unique_cities_df
dt[dt['standard_city'].str.contains(r'\d$', na=False)]
# Out:
#                 standard_city
# 75                     Puri-2
# 121            Kolkata 700034
# 256             Mumbai 400101
# 636          New Delhi-110075
# 803            Mumbai -400064
# ...                       ...
# 7147   Khopoli-Pali Road.Mh06
# 7152           Kolkata 700050
# 7230  Greater Noida, Sector 1
# 7231              Pune 411006
# 7250         New Delhi 110032
#
# [243 rows x 1 columns]

# %%
dt=df[df['standard_city'].str.contains(r'\d$', na=False)]

# %%
dt.standard_city.unique()
# Out:
# array(['Puri-2', 'Kolkata 700034', 'Mumbai 400101', 'New Delhi-110075',
#        'Mumbai -400064', 'Mumbai 400023',
#        'Kondhwa Khurd 48 .Pune  411048', 'Mumbai-400064', 'Mumbai 400057',
#        'Pune-412207', 'Vadodara 390019', 'Bengaluru-97', 'Bhilai  490020',
#        'Leh, Alt No 9419844047', 'Noida Sector 76', 'Ulhasnagar 421004',
#        'Bengaluru 560066', 'Chennai 42', 'Bengaluru -50015',
#        'Gaur City 1', 'Thane 400602', 'Delhi 110085',
#        'Thoothukudi 628008', 'Tilhar, 9717754694', 'Pune 16',
#        'Secunderabad 500094', 'Kalamassery Ph No: 9074200347',
#        'Dombivali West - 421202', 'Kolkata 700104', 'Rohtak 124001',
#        'Mumbai 400070', 'Coimbatore 641041', 'Chennai -600053',
#        'Bengaluru 560064', 'Kolkata  39', 'Pune-411014',
#        'New Delhi 110016', 'Mumbai - 400062', 'Madurai- 625004',
#        'Kolkata 700039', 'Ulhasnagar 4', 'Raichur-584101', 'Mumbai -13',
# ...

# %%
df.standard_city
# Out:
# 0              Mumbai
# 1           Bengaluru
# 2         Navi Mumbai
# 3          Puducherry
# 4             Chennai
#              ...
# 128970      Hyderabad
# 128971       Gurugram
# 128972      Hyderabad
# 128973          Halol
# 128974         Raipur
# Name: standard_city, Length: 128975, dtype: object

# %%
df.standard_city.nunique()
# Out:
# 7255

# %% [markdown]
# **Regex Creation**

# %%
df['standard_city'] = df['standard_city'].str.replace(r'[\s\-]*[\d\s\-]*$', '', regex=True).str.strip()

# %%
df.standard_city.nunique()
# Out:
# 7062

# %%
df['standard_city'] = df['standard_city'].str.replace(
    r'[\s\-:;,.]*[\d\s\-:;,.]*$', '', regex=True
).str.strip()

# %%
df.standard_city.nunique()
# Out:
# 7010

# %%
df
# Out:
#          index             Order ID      Date                        Status  \
# 0            0  405-8078784-5731545  04-30-22                     Cancelled
# 1            1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2            2  404-0687676-7273146  04-30-22                       Shipped
# 3            3  403-9615377-8133951  04-30-22                     Cancelled
# 4            4  407-1069790-7240320  04-30-22                       Shipped
# ...        ...                  ...       ...                           ...
# 128970  128970  406-6001380-7673107  05-31-22                       Shipped
# 128971  128971  402-9551604-7544318  05-31-22                       Shipped
# 128972  128972  407-9547469-3152358  05-31-22                       Shipped
# 128973  128973  402-6184140-0545956  05-31-22                       Shipped
# 128974  128974  408-7436540-8728312  05-31-22                       Shipped
#
# ...

# %%
df[df.standard_city== "Nan"]
# Out:
#          index             Order ID      Date                        Status  \
# 1871      1871  404-0566904-4825137  04-29-22                       Shipped
# 1872      1872  404-0566904-4825137  04-29-22                       Shipped
# 8752      8752  406-4003386-8768363  04-25-22                       Shipped
# 11215    11215  402-0107720-7057168  04-23-22                       Shipped
# 13252    13252  407-4532637-8415521  04-22-22                     Cancelled
# 15688    15688  404-9229894-8608305  04-21-22                       Shipped
# 16787    16787  402-4919636-4333150  04-20-22  Shipped - Delivered to Buyer
# 18351    18351  405-4927647-8064368  04-19-22                       Shipped
# 22930    22930  402-8628677-0457954  04-16-22  Shipped - Returned to Seller
# 24986    24986  406-4079063-8291520  04-15-22                     Cancelled
# 30379    30379  404-7506843-7913132  04-12-22  Shipped - Delivered to Buyer
# ...

# %%
df.standard_city.replace("Nan","Unknown",inplace=True)
# Out:
# /tmp/ipython-input-177-1395003436.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.standard_city.replace("Nan","Unknown",inplace=True)

# %%
(df.standard_city== "Unknown").sum()
# Out:
# np.int64(33)

# %%
df.standard_city.nunique()
# Out:
# 7010

# %%
(df.standard_city== "New Delhi, Other No").sum()
# Out:
# np.int64(1)

# %%
df['standard_city'] = df['standard_city'].str.split(',').str[0].str.strip()

# %%
(df.standard_city== "New Delhi, Other No").sum()
# Out:
# np.int64(0)

# %%
df.standard_city.nunique()
# Out:
# 6595

# %%
df['standard_city'] = df['standard_city'].str.replace(r'\s*\(.*?\)\s*', '', regex=True).str.strip()

# %%
df.standard_city.nunique()
# Out:
# 6511

# %%
df['standard_city'] = df['standard_city'].str.replace(r'\bNo\.?\b$', '', regex=True).str.strip()

# %%
df.standard_city.nunique()
# Out:
# 6509

# %% [markdown]
# **Remove punctuation**

# %%
df['standard_city'] = df['standard_city'].str.replace(r'^[\s\.,;:\-()]+', '', regex=True).str.strip()

# %%
(df.standard_city== "Zirakpur Punjab Mohali").sum()
# Out:
# np.int64(2)

# %%
df.standard_city.replace("Zirakpur Punjab Mohali","Zirakpur",inplace=True)
# Out:
# /tmp/ipython-input-190-3190458997.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.standard_city.replace("Zirakpur Punjab Mohali","Zirakpur",inplace=True)

# %%
df.standard_city.replace("Zira","Zirakpur",inplace=True)
# Out:
# /tmp/ipython-input-191-562542757.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.standard_city.replace("Zira","Zirakpur",inplace=True)

# %%
(df.standard_city== "Zira").sum()
# Out:
# np.int64(0)

# %%
(df.standard_city== "Udaipurudipur").sum()
# Out:
# np.int64(6)

# %%
df.standard_city.replace("Udaipurudipur","Udaipur",inplace=True)
# Out:
# /tmp/ipython-input-194-4172328767.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.standard_city.replace("Udaipurudipur","Udaipur",inplace=True)

# %%
(df.standard_city== "Udaipur").sum()
# Out:
# np.int64(218)

# %%
(df.standard_city== "Udaipurudaipur").sum()
# Out:
# np.int64(2)

# %%
df.standard_city.replace("Udaipurudaipur","Udaipur",inplace=True)
# Out:
# /tmp/ipython-input-197-3124961063.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.standard_city.replace("Udaipurudaipur","Udaipur",inplace=True)

# %%
(df.standard_city== "Chhota Udaipur").sum()
# Out:
# np.int64(2)

# %%
df.standard_city.replace("Udaipurwati Jhunjhunu","Udaipur",inplace=True)
# Out:
# /tmp/ipython-input-199-1678295583.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.standard_city.replace("Udaipurwati Jhunjhunu","Udaipur",inplace=True)

# %%
(df.standard_city== "Udaipur").sum()
# Out:
# np.int64(221)

# %%
df.standard_city.replace("Chhota Udaipur","Udaipur",inplace=True)
# Out:
# /tmp/ipython-input-201-1327210727.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.standard_city.replace("Chhota Udaipur","Udaipur",inplace=True)

# %%
(df.standard_city== "Udaipur").sum()
# Out:
# np.int64(223)

# %%
(df.standard_city== "Udaipur Mavli").sum()
# Out:
# np.int64(1)

# %%
df.standard_city.replace("Udaipur Mavli","Udaipur",inplace=True)
# Out:
# /tmp/ipython-input-204-3210153229.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.standard_city.replace("Udaipur Mavli","Udaipur",inplace=True)

# %%
(df.standard_city== "Udaipur").sum()
# Out:
# np.int64(224)

# %%
df["ship-state"].unique()
# Out:
# array(['Maharashtra', 'Karnataka', 'Puducherry', 'Tamil Nadu',
#        'Uttar Pradesh', 'Chandigarh', 'Telangana', 'Andhra Pradesh',
#        'Rajasthan', 'Delhi', 'Haryana', 'Assam', 'Jharkhand',
#        'Chhattisgarh', 'Odisha', 'Kerala', 'Madhya Pradesh',
#        'West Bengal', 'Nagaland', 'Gujarat', 'Uttarakhand', 'Bihar',
#        'Jammu & Kashmir', 'Punjab', 'Himachal Pradesh',
#        'Arunachal Pradesh', 'Manipur', 'Goa', 'Meghalaya', 'Tripura',
#        'Ladakh', 'Dadra And Nagar', 'Sikkim', nan, 'Andaman & Nicobar',
#        'Rajshthan', 'Nl', 'Mizoram', 'New Delhi',
#        'Punjab/Mohali/Zirakpur', 'Rj', 'Orissa', 'Lakshadweep', 'Pb',
#        'Apo', 'Ar', 'Pondicherry', 'Rajsthan'], dtype=object)

# %%
state_mapping = {
    'Orissa': 'Odisha',
    'Rajsthan': 'Rajasthan',
    'Rajshthan': 'Rajasthan',
    'Rj': 'Rajasthan',
    'Pb': 'Punjab',
    'Punjab/Mohali/Zirakpur': 'Punjab',
    'New Delhi': 'Delhi',
    'Pondicherry': 'Puducherry',
    'Apo': None,  # Possibly invalid or foreign
    'Ar': 'Arunachal Pradesh',
    'Nl': 'Nagaland',
    'Dadra And Nagar': 'Dadra and Nagar Haveli and Daman and Diu',  # Merged UT
    'Lakshadweep': 'Lakshadweep',
    'Andaman & Nicobar': 'Andaman and Nicobar Islands',
    'nan': None  # Handle missing data
}
# Standardize state names
df['ship-state'] = df['ship-state'].replace(state_mapping)

# Optional: Handle missing or unknown states
df['ship-state'] = df['ship-state'].fillna('Unknown')

# %%
df["ship-state"].unique()
# Out:
# array(['Maharashtra', 'Karnataka', 'Puducherry', 'Tamil Nadu',
#        'Uttar Pradesh', 'Chandigarh', 'Telangana', 'Andhra Pradesh',
#        'Rajasthan', 'Delhi', 'Haryana', 'Assam', 'Jharkhand',
#        'Chhattisgarh', 'Odisha', 'Kerala', 'Madhya Pradesh',
#        'West Bengal', 'Nagaland', 'Gujarat', 'Uttarakhand', 'Bihar',
#        'Jammu & Kashmir', 'Punjab', 'Himachal Pradesh',
#        'Arunachal Pradesh', 'Manipur', 'Goa', 'Meghalaya', 'Tripura',
#        'Ladakh', 'Dadra and Nagar Haveli and Daman and Diu', 'Sikkim',
#        'Unknown', 'Andaman and Nicobar Islands', 'Mizoram', 'Lakshadweep'],
#       dtype=object)

# %%
df.isnull().sum()
# Out:
# index                     0
# Order ID                  0
# Date                      0
# Status                    0
# Fulfilment                0
# Sales Channel             0
# ship-service-level        0
# Style                     0
# SKU                       0
# Category                  0
# Size                      0
# ASIN                      0
# Courier Status            0
# Qty                       0
# currency                  0
# Amount                    0
# ship-city                33
# ship-state                0
# ship-postal-code         33
# ship-country             33
# promotion-ids         49153
# B2B                       0
# fulfilled-by          89698
# ship-city-cleaned         0
# standard_city             0
# dtype: int64

# %%
df["ship-country"].replace(np.nan,"Unknown",inplace=True)
# Out:
# /tmp/ipython-input-218-444710209.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["ship-country"].replace(np.nan,"Unknown",inplace=True)

# %%
df.isnull().sum()
# Out:
# index                     0
# Order ID                  0
# Date                      0
# Status                    0
# Fulfilment                0
# Sales Channel             0
# ship-service-level        0
# Style                     0
# SKU                       0
# Category                  0
# Size                      0
# ASIN                      0
# Courier Status            0
# Qty                       0
# currency                  0
# Amount                    0
# ship-city                33
# ship-state                0
# ship-postal-code         33
# ship-country              0
# promotion-ids         49153
# B2B                       0
# fulfilled-by          89698
# ship-city-cleaned         0
# standard_city             0
# dtype: int64

# %%
df["ship-postal-code"].replace(np.nan,"Unknown",inplace=True)
# Out:
# /tmp/ipython-input-220-580371309.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["ship-postal-code"].replace(np.nan,"Unknown",inplace=True)

# %%
df['promotion-ids'] = df['promotion-ids'].fillna("No_Promotions")

#df.replace({"promotion-ids":{np.nan,"No_Promotions"}},inplace=True)
#df["promotion-ids"].replace(np.nan,"",inplace=True)

# %%
df.isnull().sum()
# Out:
# index                     0
# Order ID                  0
# Date                      0
# Status                    0
# Fulfilment                0
# Sales Channel             0
# ship-service-level        0
# Style                     0
# SKU                       0
# Category                  0
# Size                      0
# ASIN                      0
# Courier Status            0
# Qty                       0
# currency                  0
# Amount                    0
# ship-city                33
# ship-state                0
# ship-postal-code          0
# ship-country              0
# promotion-ids             0
# B2B                       0
# fulfilled-by          89698
# ship-city-cleaned         0
# standard_city             0
# dtype: int64

# %%
df["standard_city"].nunique()
#df["ship-city-cleaned"].nunique()
# Out:
# 6502

# %%
df.drop(["fulfilled-by"],axis=1,inplace=True)
df.drop(["ship-city"],axis=1,inplace=True)
df.drop(["ship-city-cleaned"],axis=1,inplace=True)

# %%
df.drop(["index"],axis=1,inplace=True)

# %%
df.rename(columns={'standard_city': 'Ship_city'}, inplace=True)

# %%
df.columns = [col.capitalize() for col in df.columns]

# %%
df.columns
# Out:
# Index(['Order id', 'Date', 'Status', 'Fulfilment', 'Sales channel ',
#        'Ship-service-level', 'Style', 'Sku', 'Category', 'Size', 'Asin',
#        'Courier status', 'Qty', 'Currency', 'Amount', 'Ship-state',
#        'Ship-postal-code', 'Ship-country', 'Promotion-ids', 'B2b',
#        'Ship_city'],
#       dtype='object')

# %%
df.to_csv('cleaned_data_amazon_sales.csv', index=False)
from google.colab import files
files.download('cleaned_data_amazon_sales.csv')
